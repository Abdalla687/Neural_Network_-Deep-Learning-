# %% [markdown]
# #Visualization📊

# %% [markdown]
# ![Screenshot 2025-05-08 044045.png](data:image/png;base64,...)

# %% [markdown]
# ***
# Best epoch (lowest validation loss): 309
#
#
# Root Mean Square Error (RMSE) on test data: 0.9700
# ***
